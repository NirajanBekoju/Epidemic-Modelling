# %% [markdown]
# # EPIDEMIC MODELLING with SIR model

# %% [markdown]
# S => SUSCEPTIBLE means those who could be potentially infected
# I => INFECTED means those who are infected by the epedemic disease
# R => REMOVED means those who are either recovered or death
#
# ASSUMPTION IN OUR SIR MODEL
# 1. The model is valid only for very short period of time.
# 2. Population remains constant and so no death just recovery from the diseases.
# 3. Rate of infectives is directly propotional to the contact between the persons.
#
# Using the data obtained from the epidemic modelling, we are going to analyse those data and compare the effect of various factor on epidemic spread over a society. We have considered four factors.
#     1. Infection Radius
#     2. Infection Duration
#     3. No. of people in a society
#     4. Initial infection percent

# %%
# importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Affect of Infection Radius on Epidemic Diseases
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | :- | -: | :-: |
# | Stretched | Gaussian | .843

# %% [markdown]
# Data name format : "dataf03_60_100_3" <br>
# where, <br>
# 03  => Infection Radius = 0.3<br>
# 60  => Infection Duration = 60 unit of time<br>
# 100 => No. of people = 100<br>
# 3   => Initial infection percent = 3%<br>

# %%
data = pd.read_csv("data.csv", header = None)
data.columns = ["S", "I", "R"]
data.head()
# Out:
#     S  I  R
# 0  99  1  0
# 1  99  1  0
# 2  99  1  0
# 3  99  1  0
# 4  99  1  0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S       979 non-null    int64
#  1   I       979 non-null    int64
#  2   R       979 non-null    int64
# dtypes: int64(3)
# memory usage: 23.1 KB

# %%
plt.figure(figsize=(16, 8))
plt.plot(data["S"], color = 'g', label="SUSCEPTIBLE")
plt.plot(data["I"], color = 'r', label="INFECTED")
plt.plot(data["R"], color = 'b', label="REMOVED")
plt.title("Variation of Susceptible, Infected and Removed number with time")
plt.legend()
plt.show()

# %%
derivative_data = data.diff()
derivative_data.head()
# Out:
#      S    I    R
# 0  NaN  NaN  NaN
# 1  0.0  0.0  0.0
# 2  0.0  0.0  0.0
# 3  0.0  0.0  0.0
# 4  0.0  0.0  0.0

# %%
derivative_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S       978 non-null    float64
#  1   I       978 non-null    float64
#  2   R       978 non-null    float64
# dtypes: float64(3)
# memory usage: 23.1 KB
